# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
ajedrez = cv2.imread('ajedrez_real.jpg')

# %%
plt.imshow(ajedrez)

# %%
ajedrez_gris = cv2.cvtColor(ajedrez, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(ajedrez_gris, cmap='gray')

# %%
esquinas = cv2.goodFeaturesToTrack(ajedrez_gris, 5, 0.01, 4)

# %%
esquinas = np.int0(esquinas)

# %%
esquinas
# Out:
# array([[[638, 291]],
#
#        [[420, 185]],
#
#        [[490, 234]],
#
#        [[357, 138]],
#
#        [[557, 285]]], dtype=int32)

# %%
for i in esquinas:
    x, y = i.ravel()
    #circle
    cv2.circle(ajedrez, (x,y), 4, color=(0,255,0), thickness=8)

# %%
plt.imshow(ajedrez)
